# %% [markdown]
# # Machine Learning Model Analysis
# ## Random Forest & XGBoost
#
# This notebook demonstrates training and feature importance analysis.

# %%
import sys
sys.path.append('../src')
from api_connector import Pipeline

# Run the full pipeline
pipeline = Pipeline()
# Note: Ensure data is present in /data before running
# metrics, drift = pipeline.run(model_type='xgb')
